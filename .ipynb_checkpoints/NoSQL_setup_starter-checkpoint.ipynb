# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# `IMPORT TEXT ` Import completed.39779 documents written.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['ClassDB', 'Garden', 'admin', 'config', 'fruits_db', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646c1faeffbefc80bf3a6a97'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data

new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('646c2047d47f5bbf44b16af7'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = ['BusinessTypeID', 'BusinessType']

establishments.find_one(query, fields)
# Out:
# {'_id': ObjectId('646c1faeffbefc80bf3a6a97'),
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessTypeID':''},
                         {'$set': {'BusinessTypeID': '1'}})

# %%
# Confirm that the new restaurant was updated
establishments.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('646c2047d47f5bbf44b16af7'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({})
# Out:
# 39780

# %%
# count of LocalAuthorityName is "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one({})
# Out:
# {'_id': ObjectId('646c1faeffbefc80bf3a6d7e'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude 
establishments.update_many({},[{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}}])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({},[{'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{'$set': {"RatingValue": {'$toInt':"RatingValue"}}}])
# Out:
# ---------------------------------------------------------------------------
# WriteError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15924\3187134390.py in <module>
#       1 # Change the data type from String to Integer for RatingValue
# ----> 2 establishments.update_many({},[{'$set': {"RatingValue": {'$toInt':"RatingValue"}}}])
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session)
#    1102         write_concern = self._write_concern_for(session)
#    1103         return UpdateResult(
# -> 1104             self._update_retryable(
#    1105                 filter, update, upsert, check_keys=False, multi=True,
#    1106                 write_concern=write_concern,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session)
#     875                 retryable_write=retryable_write)
#     876
# --> 877         return self.__database.client._retryable_write(
#     878             (write_concern or self.write_concern).acknowledged and not multi,
#     879             _update, session)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1550         """Internal retryable write helper."""
#    1551         with self._tmp_session(session) as s:
# -> 1552             return self._retry_with_session(retryable, func, s, None)
#    1553
#    1554     def _handle_getlasterror(self, address, error_msg):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1436         retryable = (retryable and self.retry_writes
#    1437                      and session and not session.in_transaction)
# -> 1438         return self._retry_internal(retryable, func, session, bulk)
#    1439
#    1440     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1468                             raise last_error
#    1469                         retryable = False
# -> 1470                     return func(session, sock_info, retryable)
#    1471             except ServerSelectionTimeoutError:
#    1472                 if is_retrying():
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update(session, sock_info, retryable_write)
#     867         """Internal update / replace helper."""
#     868         def _update(session, sock_info, retryable_write):
# --> 869             return self._update(
#     870                 sock_info, criteria, document, upsert=upsert,
#     871                 check_keys=check_keys, multi=multi, manipulate=manipulate,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write)
#     844             client=self.__database.client,
#     845             retryable_write=retryable_write).copy()
# --> 846         _check_write_command_response(result)
#     847         # Add the updatedExisting field for compatibility.
#     848         if result.get('n') and 'upserted' not in result:
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _check_write_command_response(result)
#     227     write_errors = result.get("writeErrors")
#     228     if write_errors:
# --> 229         _raise_last_write_error(write_errors)
#     230
#     231     error = result.get("writeConcernError")
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _raise_last_write_error(write_errors)
#     209     if error.get("code") == 11000:
#     210         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
# --> 211     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     212
#     213
#
# WriteError: Failed to parse number 'RatingValue' in $convert with no onError value: Did not consume whole string., full error: {'index': 0, 'code': 241, 'errmsg': "Failed to parse number 'RatingValue' in $convert with no onError value: Did not consume whole string."}

# %%
# Check that the coordinates and rating value are now numbers
query = {'geocode.longitude', 'geocode.latitude', 'RatingValue'}
results = establishments.find({},query)
for i in results:
    pprint(i)
# Out:
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d7e'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d7f'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d80'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d83'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d84'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d85'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d86'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d87'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d88'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d89'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d8f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d90'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d91'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d92'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d93'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d94'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d95'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d96'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d97'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d98'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d99'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6d9f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da0'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da1'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da2'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da3'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da4'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da5'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da6'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6da7'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da8'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6da9'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6daa'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6dab'),
#  'geocode': {'latitude': 51.0805695006979, 'longitude': 1.18794649942731}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dad'),
#  'geocode': {'latitude': 51.078449, 'longitude': 1.18516}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dae'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6daf'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db0'),
#  'geocode': {'latitude': 51.080446, 'longitude': 1.186825}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db1'),
#  'geocode': {'latitude': 51.079985650005, 'longitude': 1.18628335007084}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db2'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db3'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db6'),
#  'geocode': {'latitude': 51.087887, 'longitude': 1.194306}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db7'),
#  'geocode': {'latitude': 51.080224, 'longitude': 1.186067}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db8'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6db9'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dba'),
#  'geocode': {'latitude': 51.077971, 'longitude': 1.183585}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dbb'),
#  'geocode': {'latitude': 51.083232, 'longitude': 1.188902}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dbd'),
#  'geocode': {'latitude': 51.080838, 'longitude': 1.186309}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dbe'),
#  'geocode': {'latitude': 51.081735, 'longitude': 1.187056}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dbf'),
#  'geocode': {'latitude': 51.081546, 'longitude': 1.186715}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc0'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc1'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc3'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc4'),
#  'geocode': {'latitude': 51.086262, 'longitude': 1.190896}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc7'),
#  'geocode': {'latitude': 51.0818061828613, 'longitude': 1.18601894378662}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dc8'),
#  'geocode': {'latitude': 51.0877821, 'longitude': 1.1920251}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dca'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dcb'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dcc'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dcd'),
#  'geocode': {'latitude': 51.0793, 'longitude': 1.182962}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dce'),
#  'geocode': {'latitude': 51.079301, 'longitude': 1.182962}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dcf'),
#  'geocode': {'latitude': 51.0809478759766, 'longitude': 1.18431901931763}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd0'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd1'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd2'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd3'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd4'),
#  'geocode': {'latitude': 51.0917365039471, 'longitude': 1.19522100055125}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd5'),
#  'geocode': {'latitude': 51.097794, 'longitude': 1.201433}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd6'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd7'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd8'),
#  'geocode': {'latitude': 51.079905, 'longitude': 1.182875}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dd9'),
#  'geocode': {'latitude': 51.0810258, 'longitude': 1.1835476}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dda'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ddb'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ddc'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ddd'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dde'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ddf'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de1'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de2'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de3'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de4'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de5'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de6'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de7'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de8'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6de9'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dea'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6deb'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6dec'),
#  'geocode': {'latitude': 51.0798, 'longitude': 1.181483}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ded'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dee'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6def'),
#  'geocode': {'latitude': 51.0802346, 'longitude': 1.1814856}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df0'),
#  'geocode': {'latitude': 51.0797886, 'longitude': 1.1810166}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df1'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df2'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df3'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df4'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df5'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df6'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df7'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6df8'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6df9'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dfa'),
#  'geocode': {'latitude': 51.0806941, 'longitude': 1.1817227}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dfb'),
#  'geocode': {'latitude': 51.082322, 'longitude': 1.183327}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dfc'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dfd'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dfe'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6dff'),
#  'geocode': {'latitude': 51.083976, 'longitude': 1.185011}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e00'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e01'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e02'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e03'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e04'),
#  'geocode': {'latitude': 51.0816612, 'longitude': 1.1826116}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e05'),
#  'geocode': {'latitude': 51.08472, 'longitude': 1.185748}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e06'),
#  'geocode': {'latitude': 51.084721, 'longitude': 1.185748}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e07'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e08'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e09'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0a'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0b'),
#  'geocode': {'latitude': 51.080181, 'longitude': 1.181023}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0c'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0d'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0e'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e0f'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e10'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e11'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e12'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e13'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e14'),
#  'geocode': {'latitude': 51.085454, 'longitude': 1.186241}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e15'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e16'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e17'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e18'),
#  'geocode': {'latitude': 51.078587, 'longitude': 1.179115}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e19'),
#  'geocode': {'latitude': 51.0780695, 'longitude': 1.1785097}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1a'),
#  'geocode': {'latitude': 51.0798709, 'longitude': 1.1803396}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1b'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1c'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1d'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1e'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e1f'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e20'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e21'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e22'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e23'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e24'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e25'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e26'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e27'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2a'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2b'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2c'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179925}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2d'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2e'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e2f'),
#  'geocode': {'latitude': 51.081526, 'longitude': 1.181201}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e30'),
#  'geocode': {'latitude': 51.079481, 'longitude': 1.178961}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e31'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e32'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e33'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e34'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e35'),
#  'geocode': {'latitude': 51.0783483, 'longitude': 1.177752}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e37'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e38'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e39'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3a'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3b'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3c'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3d'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3e'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e3f'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e40'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e42'),
#  'geocode': {'latitude': 51.087132, 'longitude': 1.186371}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e43'),
#  'geocode': {'latitude': 51.0806446, 'longitude': 1.1796215}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e44'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e45'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e46'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e47'),
#  'geocode': {'latitude': 51.0804496, 'longitude': 1.1794011}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e48'),
#  'geocode': {'latitude': 51.083108, 'longitude': 1.181896}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e49'),
#  'geocode': {'latitude': 51.076896, 'longitude': 1.175486}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4a'),
#  'geocode': {'latitude': 51.078211, 'longitude': 1.176733}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4b'),
#  'geocode': {'latitude': 51.0782127380371, 'longitude': 1.17673301696777}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4c'),
#  'geocode': {'latitude': 51.0808513, 'longitude': 1.1794486}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4d'),
#  'geocode': {'latitude': 51.0810699462891, 'longitude': 1.17957198619843}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4e'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e4f'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e50'),
#  'geocode': {'latitude': 51.080624, 'longitude': 1.178969}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e51'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e52'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e53'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e54'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e55'),
#  'geocode': {'latitude': 51.076653, 'longitude': 1.174813}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e56'),
#  'geocode': {'latitude': 51.0776252746582, 'longitude': 1.17575001716614}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e57'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e58'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e59'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5a'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5b'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5c'),
#  'geocode': {'latitude': 51.087185, 'longitude': 1.185418}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5d'),
#  'geocode': {'latitude': 51.0758056640625, 'longitude': 1.17352676391602}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5e'),
#  'geocode': {'latitude': 51.0776458, 'longitude': 1.1753663}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e5f'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e60'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e61'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e62'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e63'),
#  'geocode': {'latitude': 51.07879, 'longitude': 1.176258}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e64'),
#  'geocode': {'latitude': 51.078513, 'longitude': 1.175897}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e65'),
#  'geocode': {'latitude': 51.0788531, 'longitude': 1.1762215}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e66'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e67'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e68'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e69'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6a'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6b'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6c'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6d'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189834}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6e'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189833}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e6f'),
#  'geocode': {'latitude': 51.0787391662598, 'longitude': 1.17591404914856}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e70'),
#  'geocode': {'latitude': 51.087382, 'longitude': 1.184803}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e71'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e72'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e73'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e74'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e75'),
#  'geocode': {'latitude': 51.0812644958496, 'longitude': 1.17841398715973}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e76'),
#  'geocode': {'latitude': 51.0806630002457, 'longitude': 1.17725700019713}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e77'),
#  'geocode': {'latitude': 51.07856, 'longitude': 1.1748}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e78'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e79'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7a'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7b'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7c'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7d'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7e'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e7f'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e80'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e81'),
#  'geocode': {'latitude': 51.0881644, 'longitude': 1.1842719}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e82'),
#  'geocode': {'latitude': 51.076413, 'longitude': 1.172055}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e83'),
#  'geocode': {'latitude': 51.079039, 'longitude': 1.174748}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e84'),
#  'geocode': {'latitude': 51.077492, 'longitude': 1.173056}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e85'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e86'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e87'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e88'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e89'),
#  'geocode': {'latitude': 51.088333, 'longitude': 1.183925}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8a'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8b'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8c'),
#  'geocode': {'latitude': 51.090286, 'longitude': 1.185859}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8d'),
#  'geocode': {'latitude': 51.089337, 'longitude': 1.18468}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8e'),
#  'geocode': {'latitude': 51.0833323, 'longitude': 1.1784191}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e8f'),
#  'geocode': {'latitude': 51.091129, 'longitude': 1.186289}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e90'),
#  'geocode': {'latitude': 51.077702, 'longitude': 1.172314}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e91'),
#  'geocode': {'latitude': 51.074167, 'longitude': 1.16866}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e93'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e94'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e95'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e96'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e97'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e98'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e99'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9a'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9b'),
#  'geocode': {'latitude': 51.082871, 'longitude': 1.177367}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9c'),
#  'geocode': {'latitude': 51.079192, 'longitude': 1.173416}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9d'),
#  'geocode': {'latitude': 51.078068, 'longitude': 1.172054}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9e'),
#  'geocode': {'latitude': 51.082381, 'longitude': 1.176219}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6e9f'),
#  'geocode': {'latitude': 51.078885, 'longitude': 1.172452}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea0'),
#  'geocode': {'latitude': 51.081154, 'longitude': 1.174678}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea1'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea2'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea3'),
#  'geocode': {'latitude': 51.075403, 'longitude': 1.168516}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea4'),
#  'geocode': {'latitude': 51.078874, 'longitude': 1.171552}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea5'),
#  'geocode': {'latitude': 51.085001, 'longitude': 1.177755}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea6'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea7'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea8'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ea9'),
#  'geocode': {'latitude': 51.088893, 'longitude': 1.181507}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eaa'),
#  'geocode': {'latitude': 51.08129, 'longitude': 1.17363}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eab'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eac'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ead'),
#  'geocode': {'latitude': 51.077243, 'longitude': 1.168984}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eae'),
#  'geocode': {'latitude': 51.0819, 'longitude': 1.17373}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eaf'),
#  'geocode': {'latitude': 51.086485, 'longitude': 1.178428}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb0'),
#  'geocode': {'latitude': 51.088124, 'longitude': 1.179997}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb1'),
#  'geocode': {'latitude': 51.088125, 'longitude': 1.179998}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb2'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb3'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb4'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb5'),
#  'geocode': {'latitude': 51.080533, 'longitude': 1.172065}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb6'),
#  'geocode': {'latitude': 51.085872, 'longitude': 1.177515}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb8'),
#  'geocode': {'latitude': 51.085365, 'longitude': 1.176952}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eb9'),
#  'geocode': {'latitude': 51.080302, 'longitude': 1.171635}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ebb'),
#  'geocode': {'latitude': 51.090168, 'longitude': 1.181609}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ebc'),
#  'geocode': {'latitude': 51.077289, 'longitude': 1.168302}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ebd'),
#  'geocode': {'latitude': 51.08885, 'longitude': 1.180133}}
# {'RatingValue': '2',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ebe'),
#  'geocode': {'latitude': 51.088806, 'longitude': 1.180073}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ebf'),
#  'geocode': {'latitude': 51.082331, 'longitude': 1.173059}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec0'),
#  'geocode': {'latitude': 51.082332, 'longitude': 1.17306}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec1'),
#  'geocode': {'latitude': 51.081795, 'longitude': 1.172295}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec2'),
#  'geocode': {'latitude': 51.090195, 'longitude': 1.18094}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec3'),
#  'geocode': {'latitude': 51.077737, 'longitude': 1.167704}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec4'),
#  'geocode': {'latitude': 51.07555, 'longitude': 1.165413}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec5'),
#  'geocode': {'latitude': 51.0769439, 'longitude': 1.1665238}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec6'),
#  'geocode': {'latitude': 51.08186, 'longitude': 1.171556}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec7'),
#  'geocode': {'latitude': 51.085552, 'longitude': 1.175336}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec8'),
#  'geocode': {'latitude': 51.085553, 'longitude': 1.175337}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6ec9'),
#  'geocode': {'latitude': 51.0932246, 'longitude': 1.1829433}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eca'),
#  'geocode': {'latitude': 51.0817527770996, 'longitude': 1.17090594768524}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ecb'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ecc'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6ecd'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed0'),
#  'geocode': {'latitude': 51.0751419067383, 'longitude': 1.16350066661835}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed1'),
#  'geocode': {'latitude': 51.076949, 'longitude': 1.164581}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed2'),
#  'geocode': {'latitude': 51.083812713623, 'longitude': 1.17163395881653}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed3'),
#  'geocode': {'latitude': 51.08382, 'longitude': 1.171591}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed4'),
#  'geocode': {'latitude': 51.07507, 'longitude': 1.162196}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed5'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed6'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed7'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed8'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ed9'),
#  'geocode': {'latitude': 51.085755, 'longitude': 1.172865}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eda'),
#  'geocode': {'latitude': 51.078911, 'longitude': 1.165543}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6edb'),
#  'geocode': {'latitude': 51.08538, 'longitude': 1.171755}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6edd'),
#  'geocode': {'latitude': 51.082833, 'longitude': 1.168524}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ee3'),
#  'geocode': {'latitude': 51.080017, 'longitude': 1.164533}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ee4'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ee5'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ee6'),
#  'geocode': {'latitude': 51.079404, 'longitude': 1.16362}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1faeffbefc80bf3a6ee9'),
#  'geocode': {'latitude': 51.076559, 'longitude': 1.160028}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eea'),
#  'geocode': {'latitude': 51.082434, 'longitude': 1.165969}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eee'),
#  'geocode': {'latitude': 51.085565, 'longitude': 1.168597}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eef'),
#  'geocode': {'latitude': 51.0813407897949, 'longitude': 1.16422498226166}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef0'),
#  'geocode': {'latitude': 51.081358, 'longitude': 1.164182}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef2'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef3'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef4'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef5'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef6'),
#  'geocode': {'latitude': 51.3344841003418, 'longitude': 1.42664802074432}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef7'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef8'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6ef9'),
#  'geocode': {'latitude': 51.336816, 'longitude': 1.428762}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6efa'),
#  'geocode': {'latitude': 51.085871, 'longitude': 1.167918}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6efb'),
#  'geocode': {'latitude': 51.076715, 'longitude': 1.158282}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6efc'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6efd'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6eff'),
#  'geocode': {'latitude': 51.3322105407715, 'longitude': 1.42320394515991}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f00'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f01'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f02'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f03'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f04'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f05'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f06'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f07'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f08'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f09'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0a'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0b'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0c'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0d'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0e'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f0f'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1faeffbefc80bf3a6f10'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'RatingValue': '5',
# ...
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab729'),
#  'geocode': {'latitude': 51.718841, 'longitude': 0.676087}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72a'),
#  'geocode': {'latitude': 51.728392, 'longitude': 0.685949}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72b'),
#  'geocode': {'latitude': 51.8888019, 'longitude': 0.8530831}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72c'),
#  'geocode': {'latitude': 51.236789, 'longitude': 0.18559}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72d'),
#  'geocode': {'latitude': 51.429019, 'longitude': 0.3789608}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72e'),
#  'geocode': {'latitude': 51.889648, 'longitude': 0.85372}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab72f'),
#  'geocode': {'latitude': 51.420986, 'longitude': 0.370713}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab730'),
#  'geocode': {'latitude': 51.1441309, 'longitude': 0.0929931}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab731'),
#  'geocode': {'latitude': 51.890992, 'longitude': 0.855041}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab732'),
#  'geocode': {'latitude': 51.652608, 'longitude': 0.607194}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab733'),
#  'geocode': {'latitude': 51.843335, 'longitude': 0.804964}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab734'),
#  'geocode': {'latitude': 51.6219834, 'longitude': 0.575533}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab735'),
#  'geocode': {'latitude': 51.6219834, 'longitude': 0.575533}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab736'),
#  'geocode': {'latitude': 51.304582, 'longitude': 0.25287}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab737'),
#  'geocode': {'latitude': 51.723235, 'longitude': 0.679836}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab738'),
#  'geocode': {'latitude': 51.426168, 'longitude': 0.375499}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab739'),
#  'geocode': {'latitude': 51.426168, 'longitude': 0.375499}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73a'),
#  'geocode': {'latitude': 51.426168, 'longitude': 0.375499}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73b'),
#  'geocode': {'latitude': 51.427076, 'longitude': 0.376409}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73c'),
#  'geocode': {'latitude': 51.6755405, 'longitude': 0.6304227}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73d'),
#  'geocode': {'latitude': 51.8896927, 'longitude': 0.8530669}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73e'),
#  'geocode': {'latitude': 51.9335087, 'longitude': 0.8990601}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab73f'),
#  'geocode': {'latitude': 51.889641, 'longitude': 0.852906}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab740'),
#  'geocode': {'latitude': 51.5271928, 'longitude': 0.4779429}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab741'),
#  'geocode': {'latitude': 51.934592, 'longitude': 0.899929}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab742'),
#  'geocode': {'latitude': 51.726256, 'longitude': 0.682216}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab743'),
#  'geocode': {'latitude': 51.8759696, 'longitude': 0.8379915}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab744'),
#  'geocode': {'latitude': 51.889481, 'longitude': 0.852053}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab745'),
#  'geocode': {'latitude': 51.8896927500955, 'longitude': 0.852214758960659}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab746'),
#  'geocode': {'latitude': 51.264071, 'longitude': 0.211168}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab747'),
#  'geocode': {'latitude': 51.878074, 'longitude': 0.839953}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab748'),
#  'geocode': {'latitude': 51.878074, 'longitude': 0.839953}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab749'),
#  'geocode': {'latitude': 51.878074, 'longitude': 0.839953}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74a'),
#  'geocode': {'latitude': 51.726239, 'longitude': 0.681766}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74b'),
#  'geocode': {'latitude': 51.5100659, 'longitude': 0.4596371}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74c'),
#  'geocode': {'latitude': 51.729428, 'longitude': 0.685054}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74d'),
#  'geocode': {'latitude': 51.729429, 'longitude': 0.685054}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74e'),
#  'geocode': {'latitude': 51.58314, 'longitude': 0.534254}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab74f'),
#  'geocode': {'latitude': 51.880061, 'longitude': 0.841807}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab750'),
#  'geocode': {'latitude': 51.880061, 'longitude': 0.841807}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab751'),
#  'geocode': {'latitude': 51.424494, 'longitude': 0.372463}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab752'),
#  'geocode': {'latitude': 51.438797, 'longitude': 0.386903}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab753'),
#  'geocode': {'latitude': 51.438797, 'longitude': 0.386903}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab754'),
#  'geocode': {'latitude': 51.438797, 'longitude': 0.386903}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab755'),
#  'geocode': {'latitude': 51.438797, 'longitude': 0.386903}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab756'),
#  'geocode': {'latitude': 51.387647, 'longitude': 0.334896}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab757'),
#  'geocode': {'latitude': 51.090953, 'longitude': 0.038213}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab758'),
#  'geocode': {'latitude': 51.4214706420898, 'longitude': 0.369040995836258}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab759'),
#  'geocode': {'latitude': 51.724128, 'longitude': 0.678904}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75a'),
#  'geocode': {'latitude': 51.586208, 'longitude': 0.536706}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75b'),
#  'geocode': {'latitude': 51.586208, 'longitude': 0.536706}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75c'),
#  'geocode': {'latitude': 51.427538, 'longitude': 0.374908}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75d'),
#  'geocode': {'latitude': 51.9428552, 'longitude': 0.906997}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75e'),
#  'geocode': {'latitude': 51.88842, 'longitude': 0.84982}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab75f'),
#  'geocode': {'latitude': 51.6249580383301, 'longitude': 0.576331973075867}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab760'),
#  'geocode': {'latitude': 51.939997, 'longitude': 0.903916}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab761'),
#  'geocode': {'latitude': 51.624969, 'longitude': 0.576319}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab762'),
#  'geocode': {'latitude': 51.74204, 'longitude': 0.697116}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab763'),
#  'geocode': {'latitude': 51.406047, 'longitude': 0.352915}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab764'),
#  'geocode': {'latitude': 51.406047, 'longitude': 0.352915}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab765'),
#  'geocode': {'latitude': 51.406047, 'longitude': 0.352915}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab766'),
#  'geocode': {'latitude': 51.6531448364258, 'longitude': 0.605167984962463}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab767'),
#  'geocode': {'latitude': 51.953538, 'longitude': 0.917891}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab768'),
#  'geocode': {'latitude': 51.4390418, 'longitude': 0.3861288}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab769'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76a'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76b'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76c'),
#  'geocode': {'latitude': 51.729606628418, 'longitude': 0.683934986591339}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76d'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76e'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab76f'),
#  'geocode': {'latitude': 51.729607, 'longitude': 0.683935}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab770'),
#  'geocode': {'latitude': 51.9414285, 'longitude': 0.9050421}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab771'),
#  'geocode': {'latitude': 51.9414285, 'longitude': 0.9050421}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab772'),
#  'geocode': {'latitude': 52.017509, 'longitude': 0.985287}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab773'),
#  'geocode': {'latitude': 51.730681, 'longitude': 0.684954}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab774'),
#  'geocode': {'latitude': 52.001895904541, 'longitude': 0.968611001968384}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab775'),
#  'geocode': {'latitude': 51.664077, 'longitude': 0.61598}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab776'),
#  'geocode': {'latitude': 51.437096, 'longitude': 0.38385}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab777'),
#  'geocode': {'latitude': 51.743171, 'longitude': 0.697604}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab778'),
#  'geocode': {'latitude': 51.6222476, 'longitude': 0.5726807}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab779'),
#  'geocode': {'latitude': 51.439748, 'longitude': 0.386133}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77a'),
#  'geocode': {'latitude': 51.728551, 'longitude': 0.682105}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77b'),
#  'geocode': {'latitude': 51.5564498901367, 'longitude': 0.504896998405457}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77c'),
#  'geocode': {'latitude': 51.55645, 'longitude': 0.504897}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77d'),
#  'geocode': {'latitude': 51.345852, 'longitude': 0.290924}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77e'),
#  'geocode': {'latitude': 51.431542, 'longitude': 0.377475}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab77f'),
#  'geocode': {'latitude': 51.431542, 'longitude': 0.377475}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab780'),
#  'geocode': {'latitude': 51.72865, 'longitude': 0.681764}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab781'),
#  'geocode': {'latitude': 51.5651874, 'longitude': 0.5133878}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab782'),
#  'geocode': {'latitude': 51.07984, 'longitude': 0.025176}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab783'),
#  'geocode': {'latitude': 51.4061554, 'longitude': 0.3514821}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab784'),
#  'geocode': {'latitude': 51.4060796, 'longitude': 0.3511778}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab785'),
#  'geocode': {'latitude': 51.730267, 'longitude': 0.682989}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab786'),
#  'geocode': {'latitude': 51.7302665710449, 'longitude': 0.682989001274109}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab787'),
#  'geocode': {'latitude': 51.730267, 'longitude': 0.682989}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab788'),
#  'geocode': {'latitude': 51.730267, 'longitude': 0.682989}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab789'),
#  'geocode': {'latitude': 51.730267, 'longitude': 0.682989}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78a'),
#  'geocode': {'latitude': 51.730267, 'longitude': 0.682989}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78b'),
#  'geocode': {'latitude': 51.557137, 'longitude': 0.504689}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78c'),
#  'geocode': {'latitude': 51.557137, 'longitude': 0.504689}}
# {'RatingValue': '3',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78d'),
#  'geocode': {'latitude': 51.557137, 'longitude': 0.504689}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78e'),
#  'geocode': {'latitude': 51.557137, 'longitude': 0.504689}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab78f'),
#  'geocode': {'latitude': 51.254953, 'longitude': 0.198705}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab790'),
#  'geocode': {'latitude': 51.6522827148438, 'longitude': 0.60199898481369}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab791'),
#  'geocode': {'latitude': 51.165128, 'longitude': 0.108838}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab792'),
#  'geocode': {'latitude': 51.730248, 'longitude': 0.682264}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab793'),
#  'geocode': {'latitude': 51.690592, 'longitude': 0.641196}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab794'),
#  'geocode': {'latitude': 51.730258, 'longitude': 0.682192}}
# {'RatingValue': '4',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab795'),
#  'geocode': {'latitude': 51.7302589416504, 'longitude': 0.682192027568817}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab796'),
#  'geocode': {'latitude': 51.402945, 'longitude': 0.347062}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab797'),
#  'geocode': {'latitude': 51.6229625, 'longitude': 0.5712474}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab798'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab799'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79a'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79b'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79c'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79d'),
#  'geocode': {'latitude': 51.5777272, 'longitude': 0.5248257}}
# {'RatingValue': None,
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79e'),
#  'geocode': {'latitude': 51.884916, 'longitude': 0.843015}}
# {'RatingValue': '1',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab79f'),
#  'geocode': {'latitude': 51.884754, 'longitude': 0.842839}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab7a0'),
#  'geocode': {'latitude': 51.884754, 'longitude': 0.842839}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab7a1'),
#  'geocode': {'latitude': 51.884754, 'longitude': 0.842839}}
# {'RatingValue': '5',
#  '_id': ObjectId('646c1fb3ffbefc80bf3ab7a2'),
#  'geocode':
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
